# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir("/content/drive/MyDrive/DeepCMorph-main")

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import os
import numpy as np
from torch.utils.data import DataLoader, random_split
from torchvision import transforms, datasets
from torchvision.datasets import ImageFolder
from sklearn.metrics import classification_report
from timm.models.swin_transformer import swin_base_patch4_window7_224
import timm
import matplotlib.pyplot as plt

# Device setup
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Transforms
train_transform = transforms.Compose([
    transforms.RandomResizedCrop(256, scale=(0.8, 1.0)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.RandomAffine(degrees=0, translate=(0.1, 0.1)),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.RandomErasing(p=0.2),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

val_test_transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Load dataset (without transform)
data_dir = "/content/drive/MyDrive/DeepCMorph-main/data/biomedical/biomedical"
full_dataset = ImageFolder(root=os.path.join(data_dir, "train"))

# Split into train/val
val_ratio = 0.2
val_size = int(val_ratio * len(full_dataset))
train_size = len(full_dataset) - val_size
train_dataset, val_dataset = random_split(full_dataset, [train_size, val_size])

# Assign transforms
train_dataset.dataset.transform = train_transform
val_dataset.dataset.transform = val_test_transform

# Test set
test_dataset = ImageFolder(root=os.path.join(data_dir, "test"), transform=val_test_transform)

# DataLoaders
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True, num_workers=2)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False, num_workers=2)

torch.cuda.empty_cache()

# Hybrid Vision Transformer Encoder
class HybridViTEncoder(nn.Module):
    def __init__(self, img_size=256, patch_size=16, embed_dim=768, depth=6, num_heads=8):
        super(HybridViTEncoder, self).__init__()
        self.cnn_backbone = timm.create_model("resnet50", pretrained=True, num_classes=0, global_pool="")
        self.projection = nn.Linear(2048, embed_dim)
        self.vit = timm.create_model("vit_base_patch16_224", pretrained=True, num_classes=0)

    def forward(self, x):
        x = self.cnn_backbone(x)
        x = x.flatten(2).transpose(1, 2)
        x = self.projection(x)
        b, n, c = x.shape
        h = w = int(n ** 0.5)
        return x.transpose(1, 2).view(b, c, h, w)

# CNN-based Decoder
class CNNDecoder(nn.Module):
    def __init__(self, embed_dim=768, num_classes=4):
        super(CNNDecoder, self).__init__()
        self.conv1 = nn.Conv2d(embed_dim, 512, kernel_size=3, padding=1)
        self.dropout1 = nn.Dropout(0.3)
        self.conv2 = nn.Conv2d(512, 256, kernel_size=3, padding=1)
        self.dropout2 = nn.Dropout(0.3)
        self.conv3 = nn.Conv2d(256, num_classes, kernel_size=1)
        self.self_attn = nn.MultiheadAttention(embed_dim=num_classes, num_heads=4)
        self.batch_norm = nn.BatchNorm2d(256)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = self.dropout1(x)
        x = F.relu(self.conv2(x))
        x = self.dropout2(x)
        x = self.batch_norm(x)
        segmentation_map = self.conv3(x)
        b, c, h, w = segmentation_map.shape
        x = segmentation_map.view(b, c, -1).permute(2, 0, 1)
        x, _ = self.self_attn(x, x, x)
        x = x.permute(1, 2, 0).view(b, c, h, w)
        classification_map = torch.argmax(x, dim=1, keepdim=True)
        return segmentation_map, classification_map

# Unified Model
class UnifiedModel(nn.Module):
    def __init__(self, num_classes=4):
        super(UnifiedModel, self).__init__()
        self.segmentation_model = nn.Sequential(HybridViTEncoder(), CNNDecoder())
        self.classification_model = swin_base_patch4_window7_224(pretrained=True, num_classes=num_classes)

    def forward(self, x):
        segmentation_map, _ = self.segmentation_model(x)
        segmentation_map = F.interpolate(segmentation_map, size=(224, 224), mode="bilinear", align_corners=False)
        x = F.interpolate(x, size=(224, 224), mode="bilinear", align_corners=False)
        combined_input = torch.cat((x, segmentation_map), dim=1)
        combined_input = combined_input[:, :3, :, :]  # Swin expects 3 channels
        classification_output = self.classification_model(combined_input)
        return classification_output

# Initialize model
unified_model = UnifiedModel().to(device)

# Optimizer, Scheduler, Loss
optimizer = torch.optim.Adam(unified_model.parameters(), lr=0.0001)
scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=10, T_mult=2)
criterion = nn.CrossEntropyLoss(label_smoothing=0.1)
scaler = torch.amp.GradScaler(device="cuda")
def compute_segmentation_metrics(preds, targets, num_classes):
    ious = []
    dice_scores = []
    for cls in range(num_classes):
        pred_cls = (preds == cls).astype(np.uint8)
        target_cls = (targets == cls).astype(np.uint8)

        intersection = (pred_cls & target_cls).sum()
        union = (pred_cls | target_cls).sum()
        iou = intersection / (union + 1e-6)
        ious.append(iou)

        dice = (2. * intersection) / (pred_cls.sum() + target_cls.sum() + 1e-6)
        dice_scores.append(dice)
    return ious, dice_scores

# === Training Function with Resume Checkpoint & Logging ===
def train_model(model, dataloader, val_loader, criterion, optimizer, scheduler,
                num_epochs=20, checkpoint_path="unified_checkpoint20.pth", best_model_path="best_model.pth"):
    start_epoch = 0
    best_val_acc = 0
    train_losses, val_accuracies = [], []

    if os.path.exists(checkpoint_path):
        checkpoint = torch.load(checkpoint_path, weights_only=False)
        model.load_state_dict(checkpoint['model_state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        start_epoch = checkpoint['epoch'] + 1
        best_val_acc = checkpoint.get('best_val_acc', 0)
        print(f"Resuming training from epoch {start_epoch}")

    for epoch in range(start_epoch, num_epochs):
        model.train()
        running_loss, correct, total = 0.0, 0, 0

        for images, labels in dataloader:
            images, labels = images.to(device), labels.to(device).long()
            optimizer.zero_grad()

            with torch.autocast(device_type="cuda"):
                outputs = model(images)
                loss = criterion(outputs, labels)

            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()
            scheduler.step(epoch + images.size(0) / len(dataloader))

            running_loss += loss.item()
            _, preds = torch.max(outputs, 1)
            correct += (preds == labels).sum().item()
            total += labels.size(0)

        epoch_loss = running_loss / len(dataloader)
        train_acc = correct / total
        val_acc = evaluate_model(model, val_loader, silent=True)

        train_losses.append(epoch_loss)
        val_accuracies.append(val_acc)

        print(f"Epoch {epoch+1}, Loss: {epoch_loss:.4f}, Train Acc: {train_acc:.4f}, Val Acc: {val_acc:.4f}")

        torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'best_val_acc': best_val_acc
        }, checkpoint_path)

        if val_acc > best_val_acc:
            best_val_acc = val_acc
            torch.save(model.state_dict(), best_model_path)
            print(f"✅ Best model saved with val acc: {val_acc:.4f}")

    # Plot learning curves
    plt.figure(figsize=(8,5))
    plt.plot(train_losses, label='Train Loss')
    plt.plot(val_accuracies, label='Val Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Value')
    plt.title('Training Curve')
    plt.legend()
    plt.savefig("training_curve.png")
    plt.close()

# === Evaluate and Save Segmentation Outputs ===
def compute_segmentation_metrics(preds, targets, num_classes):
    ious = []
    dice_scores = []
    for cls in range(num_classes):
        pred_cls = (preds == cls).astype(np.uint8)
        target_cls = (targets == cls).astype(np.uint8)

        intersection = (pred_cls & target_cls).sum()
        union = (pred_cls | target_cls).sum()
        iou = intersection / (union + 1e-6)
        ious.append(iou)

        dice = (2. * intersection) / (pred_cls.sum() + target_cls.sum() + 1e-6)
        dice_scores.append(dice)
    return ious, dice_scores

# === Plotting Functions ===
def plot_segmentation_metrics(ious, dices, class_names=None, save_path="segmentation_metrics.png"):
    import numpy as np
    import matplotlib.pyplot as plt

    num_classes = len(ious)
    x = np.arange(num_classes)
    class_names = class_names or [f"Class {i}" for i in range(num_classes)]

    plt.figure(figsize=(12, 6))
    width = 0.35
    plt.bar(x - width/2, ious, width, label='IoU', color='tab:green')
    plt.bar(x + width/2, dices, width, label='Dice', color='tab:purple')

    plt.xlabel("Classes", fontsize=14)
    plt.ylabel("Score", fontsize=14)
    plt.title("Per-Class IoU and Dice Coefficient", fontsize=16)
    plt.xticks(x, class_names, fontsize=12)
    plt.yticks(fontsize=12)
    plt.ylim(0, 1)
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    plt.show()

def plot_confusion_matrix(y_true, y_pred, class_names=None, save_path="confusion_matrix.png"):
    from sklearn.metrics import confusion_matrix
    import seaborn as sns
    import matplotlib.pyplot as plt

    cm = confusion_matrix(y_true, y_pred)
    class_names = class_names or [f"Class {i}" for i in range(len(cm))]

    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
    plt.title("Confusion Matrix", fontsize=16)
    plt.xlabel("Predicted Label", fontsize=14)
    plt.ylabel("True Label", fontsize=14)
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    plt.show()
def evaluate_model(model, dataloader, silent=False, save_segmentations=True):
    model.eval()
    all_preds, all_labels = [], []
    all_seg_preds, all_seg_labels = [], []

    with torch.no_grad():
        for i, (images, labels) in enumerate(dataloader):
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, preds = torch.max(outputs, 1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

            # For segmentation map extraction
            seg_model = model.segmentation_model
            seg_map, cls_map = seg_model(images)
            seg_preds = torch.argmax(seg_map, dim=1)
            all_seg_preds.append(seg_preds.cpu().numpy())
            all_seg_labels.append(labels.cpu().numpy())

            # if save_segmentations:
            #     os.makedirs("seg_outputs", exist_ok=True)
            #     for j in range(images.size(0)):
            #         plt.imsave(f"seg_outputs/sample_{i}_{j}.png", seg_preds[j].cpu().numpy())

    if not silent:
        print("Classification Report:")
        print(classification_report(all_labels, all_preds))

    cls_acc = np.mean(np.array(all_preds) == np.array(all_labels))
    seg_preds_np = np.concatenate(all_seg_preds)
    seg_labels_np = np.concatenate(all_seg_labels)
    #ious, dices = compute_segmentation_metrics(seg_preds_np, seg_labels_np, num_classes=4)

    print("\nClassification Accuracy:", cls_acc)
    #print("Mean IoU:", np.mean(ious))
    #print("Mean Dice Coefficient:", np.mean(dices))

    plot_confusion_matrix(all_labels, all_preds, class_names=["Class A", "Class B", "Class C", "Class D"])
   # plot_segmentation_metrics(ious, dices, class_names=["Background", "Class A", "Class B", "Class C"])

    return cls_acc

# === Run training and evaluation ===
#train_model(unified_model, train_loader, val_loader, criterion, optimizer, scheduler)
unified_model.load_state_dict(torch.load("best_model.pth"))
evaluate_model(unified_model, test_loader)

# # Training function
# def train_model(model, dataloader, val_loader, criterion, optimizer, scheduler, num_epochs=50, checkpoint_path="best_model.pth"):
#     best_val_acc = 0

#     for epoch in range(num_epochs):
#         model.train()
#         running_loss, correct, total = 0.0, 0, 0
#         for images, labels in dataloader:
#             images, labels = images.to(device), labels.to(device).long()
#             optimizer.zero_grad()

#             with torch.autocast(device_type="cuda"):
#                 outputs = model(images)
#                 loss = criterion(outputs, labels)

#             scaler.scale(loss).backward()
#             scaler.step(optimizer)
#             scaler.update()
#             scheduler.step(epoch + images.size(0) / len(dataloader))

#             running_loss += loss.item()
#             _, preds = torch.max(outputs, 1)
#             correct += (preds == labels).sum().item()
#             total += labels.size(0)

#         accuracy = correct / total
#         print(f"Epoch {epoch+1}, Train Loss: {running_loss/len(dataloader):.4f}, Train Acc: {accuracy:.4f}")

#         # Validation
#         val_acc = evaluate_model(model, val_loader, silent=True)
#         if val_acc > best_val_acc:
#             best_val_acc = val_acc
#             torch.save(model.state_dict(), checkpoint_path)
#             print(f"✅ Best model updated at epoch {epoch+1} with val acc: {val_acc:.4f}")

# def evaluate_model(model, dataloader, silent=False):
#     model.eval()
#     all_preds, all_labels = [], []
#     with torch.no_grad():
#         for images, labels in dataloader:
#             images, labels = images.to(device), labels.to(device)
#             outputs = model(images)
#             _, preds = torch.max(outputs, 1)
#             all_preds.extend(preds.cpu().numpy())
#             all_labels.extend(labels.cpu().numpy())
#     if not silent:
#         print("Final Classification Report:")
#         print(classification_report(all_labels, all_preds))
#     accuracy = np.mean(np.array(all_preds) == np.array(all_labels))
#     return accuracy

# # Train and Evaluate
# train_model(unified_model, train_loader, val_loader, criterion, optimizer, scheduler, num_epochs=50)
# unified_model.load_state_dict(torch.load("best_model.pth"))
# evaluate_model(unified_model, test_loader)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.93      0.88       565
#            1       0.79      0.70      0.75       570
#            2       0.73      0.88      0.80       565
#            3       0.84      0.51      0.63       300
#
#     accuracy                           0.79      2000
#    macro avg       0.80      0.76      0.76      2000
# weighted avg       0.79      0.79      0.78      2000
#
#
# Classification Accuracy: 0.788
# np.float64(0.788)

# %%
# Restart the runtime first (via Runtime > Restart runtime in the menu), then run:
# !pip install --upgrade torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# !pip install timm --upgrade
# !pip install --upgrade transformers

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import os
import numpy as np
from torch.utils.data import DataLoader, random_split
from torchvision import transforms, datasets
from torchvision.datasets import ImageFolder
from sklearn.metrics import classification_report
from timm.models.swin_transformer import swin_base_patch4_window7_224
import timm
import matplotlib.pyplot as plt

# Device setup
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Data transformations with stronger augmentation
transform = transforms.Compose([
    transforms.RandomResizedCrop(256, scale=(0.8, 1.0)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.RandomAffine(degrees=0, translate=(0.1, 0.1)),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.ToTensor(),  # Moved before RandomErasing
    transforms.RandomErasing(p=0.2),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Load dataset
data_dir = "/content/drive/MyDrive/DeepCMorph-main/data/biomedical/biomedical"
full_dataset = ImageFolder(root=os.path.join(data_dir, "train"), transform=transform)
test_dataset = ImageFolder(root=os.path.join(data_dir, "test"), transform=transform)

# Split train into train/val
val_ratio = 0.2
val_size = int(val_ratio * len(full_dataset))
train_size = len(full_dataset) - val_size
train_dataset, val_dataset = random_split(full_dataset, [train_size, val_size])

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True, num_workers=2)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False, num_workers=2)

torch.cuda.empty_cache()

# Hybrid Vision Transformer Encoder
class HybridViTEncoder(nn.Module):
    def __init__(self, img_size=256, patch_size=16, embed_dim=768, depth=6, num_heads=8):
        super(HybridViTEncoder, self).__init__()
        self.cnn_backbone = timm.create_model("resnet50", pretrained=True, num_classes=0, global_pool="")
        self.projection = nn.Linear(2048, embed_dim)
        self.vit = timm.create_model("vit_base_patch16_224", pretrained=True, num_classes=0)

    def forward(self, x):
        x = self.cnn_backbone(x)
        x = x.flatten(2).transpose(1, 2)
        x = self.projection(x)
        b, n, c = x.shape
        h = w = int(n ** 0.5)
        return x.transpose(1, 2).view(b, c, h, w)

# CNN-based Decoder with Dropout & Attention Layer
class CNNDecoder(nn.Module):
    def __init__(self, embed_dim=768, num_classes=4):
        super(CNNDecoder, self).__init__()
        self.conv1 = nn.Conv2d(embed_dim, 512, kernel_size=3, padding=1)
        self.dropout1 = nn.Dropout(0.3)
        self.conv2 = nn.Conv2d(512, 256, kernel_size=3, padding=1)
        self.dropout2 = nn.Dropout(0.3)
        self.conv3 = nn.Conv2d(256, num_classes, kernel_size=1)
        self.self_attn = nn.MultiheadAttention(embed_dim=num_classes, num_heads=4)
        self.batch_norm = nn.BatchNorm2d(256)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = self.dropout1(x)
        x = F.relu(self.conv2(x))
        x = self.dropout2(x)
        x = self.batch_norm(x)
        segmentation_map = self.conv3(x)
        b, c, h, w = segmentation_map.shape
        x = segmentation_map.view(b, c, -1).permute(2, 0, 1)
        x, _ = self.self_attn(x, x, x)
        x = x.permute(1, 2, 0).view(b, c, h, w)
        classification_map = torch.argmax(x, dim=1, keepdim=True)
        return segmentation_map, classification_map

# Unified Model with Swin Transformer Classifier
class UnifiedModel(nn.Module):
    def __init__(self, num_classes=4):
        super(UnifiedModel, self).__init__()
        self.segmentation_model = nn.Sequential(HybridViTEncoder(), CNNDecoder())
        self.classification_model = swin_base_patch4_window7_224(pretrained=True, num_classes=num_classes)

    def forward(self, x):
        segmentation_map, _ = self.segmentation_model(x)
        segmentation_map = F.interpolate(segmentation_map, size=(224, 224), mode="bilinear", align_corners=False)
        x = F.interpolate(x, size=(224, 224), mode="bilinear", align_corners=False)
        combined_input = torch.cat((x, segmentation_map), dim=1)
        combined_input = combined_input[:, :3, :, :]  # Swin only accepts 3-channel input
        classification_output = self.classification_model(combined_input)
        return classification_output

# Initialize Model
unified_model = UnifiedModel().to(device)

# Optimizer, Scheduler, Loss
optimizer = torch.optim.Adam(unified_model.parameters(), lr=0.0001)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=10)
criterion = nn.CrossEntropyLoss(label_smoothing=0.1)
scaler = torch.amp.GradScaler()

# Training Function

def train_model(model, dataloader, val_loader, criterion, optimizer, scheduler, num_epochs=25, checkpoint_path="unified_checkpoint6.pth"):
    start_epoch = 0
    best_val_acc = 0
    if os.path.exists(checkpoint_path):
        checkpoint = torch.load(checkpoint_path)
        model.load_state_dict(checkpoint['model_state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        start_epoch = checkpoint['epoch'] + 1
        print(f"Resuming training from epoch {start_epoch}")

    for epoch in range(start_epoch, num_epochs):
        model.train()
        running_loss, correct, total = 0.0, 0, 0
        for images, labels in dataloader:
            images, labels = images.to(device), labels.to(device).long()
            optimizer.zero_grad()

            with torch.amp.autocast("cuda"):
                outputs = model(images)
                loss = criterion(outputs, labels)

            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()
            scheduler.step()

            running_loss += loss.item()
            _, preds = torch.max(outputs, 1)
            correct += (preds == labels).sum().item()
            total += labels.size(0)

        accuracy = correct / total
        print(f"Epoch {epoch+1}, Train Loss: {running_loss/len(dataloader):.4f}, Train Acc: {accuracy:.4f}")

        # Validation
        val_acc = evaluate_model(model, val_loader, silent=True)
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            torch.save({'epoch': epoch, 'model_state_dict': model.state_dict(), 'optimizer_state_dict': optimizer.state_dict()}, checkpoint_path)
            print(f"Best model updated at epoch {epoch+1} with val acc: {val_acc:.4f}")

def evaluate_model(model, dataloader, silent=False):
    model.eval()
    all_preds, all_labels = [], []
    with torch.no_grad():
        for images, labels in dataloader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, preds = torch.max(outputs, 1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    if not silent:
        print("Final Classification Report:")
        print(classification_report(all_labels, all_preds))
    accuracy = np.mean(np.array(all_preds) == np.array(all_labels))
    return accuracy

# Train and Evaluate
train_model(unified_model, train_loader, val_loader, criterion, optimizer, scheduler, num_epochs=25)
evaluate_model(unified_model, test_loader)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/102M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/353M [00:00<?, ?B/s]
# Resuming training from epoch 14
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-d1d901825097> in <cell line: 0>()
#     171
#     172 # Train and Evaluate
# --> 173 train_model(unified_model, train_loader, val_loader, criterion, optimizer, scheduler, num_epochs=25)
#     174 evaluate_model(unified_model, test_loader)
#
# <ipython-input-3-d1d901825097> in train_model(model, dataloader, val_loader, criterion, optimizer, scheduler, num_epochs, checkpoint_path)
#     126         model.train()
#     127         running_loss, correct, total = 0.0, 0, 0
# --> 128         for images, labels in dataloader:
#     129             images, labels = images.to(device), labels.to(device).long()
#     130             optimizer.zero_grad()
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     706                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     707                 self._reset()  # type: ignore[call-arg]
# --> 708             data = self._next_data()
#     709             self._num_yielded += 1
#     710             if (
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1456
#    1457             assert not self._shutdown and self._tasks_outstanding > 0
# -> 1458             idx, data = self._get_data()
#    1459             self._tasks_outstanding -= 1
#    1460             if self._dataset_kind == _DatasetKind.Iterable:
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py in _get_data(self)
#    1418         else:
#    1419             while True:
# -> 1420                 success, data = self._try_get_data()
#    1421                 if success:
#    1422                     return data
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#    1249         #   (bool: whether successfully get data, any: data if successful else None)
#    1250         try:
# -> 1251             data = self._data_queue.get(timeout=timeout)
#    1252             return (True, data)
#    1253         except Exception as e:
#
# /usr/lib/python3.11/multiprocessing/queues.py in get(self, block, timeout)
#     111                 if block:
#     112                     timeout = deadline - time.monotonic()
# --> 113                     if not self._poll(timeout):
#     114                         raise Empty
#     115                 elif not self._poll():
#
# /usr/lib/python3.11/multiprocessing/connection.py in poll(self, timeout)
#     255         self._check_closed()
#     256         self._check_readable()
# --> 257         return self._poll(timeout)
#     258
#     259     def __enter__(self):
#
# /usr/lib/python3.11/multiprocessing/connection.py in _poll(self, timeout)
#     438
#     439     def _poll(self, timeout):
# --> 440         r = wait([self], timeout)
#     441         return bool(r)
#     442
#
# /usr/lib/python3.11/multiprocessing/connection.py in wait(object_list, timeout)
#     946
#     947             while True:
# --> 948                 ready = selector.select(timeout)
#     949                 if ready:
#     950                     return [key.fileobj for (key, events) in ready]
#
# /usr/lib/python3.11/selectors.py in select(self, timeout)
#     413         ready = []
#     414         try:
# --> 415             fd_event_list = self._selector.poll(timeout)
#     416         except InterruptedError:
#     417             return ready
#
# KeyboardInterrupt:

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import os
import numpy as np
from torch.utils.data import DataLoader
from torchvision import transforms, datasets
from torchvision.datasets import ImageFolder
from sklearn.metrics import classification_report
from timm.models.vision_transformer import VisionTransformer
import timm
import matplotlib.pyplot as plt

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Data transformations with augmentation
transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.RandomAffine(degrees=0, translate=(0.1, 0.1)),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Load dataset
data_dir = "/content/drive/MyDrive/DeepCMorph-main/data/biomedical/biomedical"
train_dataset = ImageFolder(root=os.path.join(data_dir, "train"), transform=transform)
test_dataset = ImageFolder(root=os.path.join(data_dir, "test"), transform=transform)

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False, num_workers=2)

torch.cuda.empty_cache()

# Hybrid Vision Transformer Encoder
class HybridViTEncoder(nn.Module):
    def __init__(self, img_size=256, patch_size=16, embed_dim=768, depth=6, num_heads=8):
        super(HybridViTEncoder, self).__init__()

        # CNN Backbone (ResNet-50 without classification head)
        self.cnn_backbone = timm.create_model("resnet50", pretrained=True, num_classes=0, global_pool="")

        # Linear Projection to match ViT embed_dim
        self.projection = nn.Linear(2048, embed_dim)

        # Vision Transformer
        self.vit = VisionTransformer(
            img_size=img_size // 4,  # Adjusted for CNN downscaling
            patch_size=patch_size,
            in_chans=embed_dim,  # Adjusted input channels
            embed_dim=embed_dim,
            depth=depth,
            num_heads=num_heads,
            num_classes=0
        )

    def forward(self, x):
        # Extract features using ResNet-50
        x = self.cnn_backbone(x)  # Shape: (B, 2048, H/32, W/32)

        # Reshape for ViT processing
        x = x.flatten(2).transpose(1, 2)  # Shape: (B, Num_Patches, 2048)
        x = self.projection(x)  # Shape: (B, Num_Patches, embed_dim)

        # Pass through ViT
        x = self.vit.blocks(x)

        # Reshape to feature map
        b, n, c = x.shape
        h = w = int(n ** 0.5)
        return x.transpose(1, 2).view(b, c, h, w)  # Shape: (B, C, H, W)

# CNN-based Decoder with Attention Layer
class CNNDecoder(nn.Module):
    def __init__(self, embed_dim=768, num_classes=4):
        super(CNNDecoder, self).__init__()
        self.conv1 = nn.Conv2d(embed_dim, 512, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(512, 256, kernel_size=3, padding=1)
        self.conv3 = nn.Conv2d(256, num_classes, kernel_size=1)
        self.self_attn = nn.MultiheadAttention(embed_dim=num_classes, num_heads=4)
        self.batch_norm = nn.BatchNorm2d(256)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = self.batch_norm(x)
        segmentation_map = self.conv3(x)
        b, c, h, w = segmentation_map.shape
        x = segmentation_map.view(b, c, -1).permute(2, 0, 1)
        x, _ = self.self_attn(x, x, x)
        x = x.permute(1, 2, 0).view(b, c, h, w)
        classification_map = torch.argmax(x, dim=1, keepdim=True)
        return segmentation_map, classification_map

# Unified Model with Hybrid ViT Classifier
class UnifiedModel(nn.Module):
    def __init__(self, num_classes=4):
        super(UnifiedModel, self).__init__()
        self.segmentation_model = nn.Sequential(HybridViTEncoder(), CNNDecoder())
        self.classification_model = VisionTransformer(
            img_size=256, patch_size=8, in_chans=3 + num_classes,
            embed_dim=768, depth=6, num_heads=8, num_classes=num_classes,
            drop_rate=0.2
        )

    def forward(self, x):
        segmentation_map, _ = self.segmentation_model(x)
        segmentation_map = F.interpolate(segmentation_map, size=(256, 256), mode="bilinear", align_corners=False)
        combined_input = torch.cat((x, segmentation_map), dim=1)
        classification_output = self.classification_model(combined_input)
        return classification_output

# Initialize Model
unified_model = UnifiedModel().to(device)

# Optimizer and Loss
optimizer = torch.optim.Adam(unified_model.parameters(), lr=0.0001)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=10)
criterion = nn.CrossEntropyLoss(label_smoothing=0.1)
scaler = torch.amp.GradScaler()

# Training Function
def train_model(model, dataloader, criterion, optimizer, scheduler, num_epochs=35, checkpoint_path="unified_checkpoint5.pth"):
    start_epoch = 0
    if os.path.exists(checkpoint_path):
        checkpoint = torch.load(checkpoint_path)
        model.load_state_dict(checkpoint['model_state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        start_epoch = checkpoint['epoch'] + 1
        print(f"Resuming training from epoch {start_epoch}")

    model.train()
    for epoch in range(start_epoch, num_epochs):
        running_loss, correct, total = 0.0, 0, 0
        for images, labels in dataloader:
            images, labels = images.to(device), labels.to(device).long()
            optimizer.zero_grad()

            with torch.amp.autocast("cuda"):
                outputs = model(images)
                loss = criterion(outputs, labels)

            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()
            scheduler.step()

            running_loss += loss.item()
            _, preds = torch.max(outputs, 1)
            correct += (preds == labels).sum().item()
            total += labels.size(0)

        accuracy = correct / total
        print(f"Epoch {epoch+1}, Loss: {running_loss/len(dataloader):.4f}, Accuracy: {accuracy:.4f}")
        torch.save({'epoch': epoch, 'model_state_dict': model.state_dict(), 'optimizer_state_dict': optimizer.state_dict()}, checkpoint_path)
def evaluate_model(model, dataloader):
    model.eval()
    all_preds, all_labels = [], []
    with torch.no_grad():
        for images, labels in dataloader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, preds = torch.max(outputs, 1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    print("Final Classification Report:")
    print(classification_report(all_labels, all_preds))
# Train and Evaluate the Model
train_model(unified_model, train_loader, criterion, optimizer, scheduler, num_epochs=35)
evaluate_model(unified_model, test_loader)
# Out:
# Resuming training from epoch 30
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py:227: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn(
# Epoch 31, Loss: 0.5926, Accuracy: 0.8793
# Epoch 32, Loss: 0.5825, Accuracy: 0.8843
# Epoch 33, Loss: 0.5779, Accuracy: 0.8867
# Epoch 34, Loss: 0.5739, Accuracy: 0.8879
# Epoch 35, Loss: 0.5664, Accuracy: 0.8922
# Final Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.90      0.87       565
#            1       0.78      0.69      0.73       570
#            2       0.69      0.87      0.77       565
#            3       0.80      0.47      0.60       300
#
#     accuracy                           0.77      2000
#    macro avg       0.78      0.73      0.74      2000
# weighted avg       0.78      0.77      0.76      2000

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import os
import numpy as np
from torch.utils.data import DataLoader
from torchvision import transforms, datasets
from torchvision.datasets import ImageFolder
from sklearn.metrics import classification_report
from timm.models.vision_transformer import VisionTransformer
import matplotlib.pyplot as plt

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Data transformations with standard normalization
transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Load dataset
data_dir = "/content/drive/MyDrive/DeepCMorph-main/data/biomedical/biomedical"
train_dataset = ImageFolder(root=os.path.join(data_dir, "train"), transform=transform)
test_dataset = ImageFolder(root=os.path.join(data_dir, "test"), transform=transform)

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False, num_workers=2)

torch.cuda.empty_cache()

# Vision Transformer Encoder with fixed output shape
class ViTEncoder(nn.Module):
    def __init__(self, img_size=256, patch_size=16, embed_dim=768, depth=6, num_heads=8):
        super(ViTEncoder, self).__init__()
        self.vit = VisionTransformer(
            img_size=img_size, patch_size=patch_size, in_chans=3,
            embed_dim=embed_dim, depth=depth, num_heads=num_heads, num_classes=0
        )

    def forward(self, x):
        x = self.vit.patch_embed(x)
        x = self.vit.pos_drop(x)
        for blk in self.vit.blocks:
            x = blk(x)
        b, n, c = x.shape  # Ensure expected dimensions
        h = w = int(n ** 0.5)  # Infer spatial size
        return x.transpose(1, 2).view(b, c, h, w)

# CNN-based Decoder with Attention Layer
class CNNDecoder(nn.Module):
    def __init__(self, embed_dim=768, num_classes=4):
        super(CNNDecoder, self).__init__()
        self.conv1 = nn.Conv2d(embed_dim, 256, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(256, num_classes, kernel_size=1)
        self.attn = nn.MultiheadAttention(embed_dim=num_classes, num_heads=2)  # Adjusted embed_dim and num_heads

    def forward(self, x):
        x = F.relu(self.conv1(x))
        segmentation_map = self.conv2(x)
        b, c, h, w = segmentation_map.shape
        x = segmentation_map.view(b, c, -1).permute(2, 0, 1)
        x, _ = self.attn(x, x, x)
        x = x.permute(1, 2, 0).view(b, c, h, w)
        classification_map = torch.argmax(x, dim=1, keepdim=True)
        return segmentation_map, classification_map

# Unified Model with ViT Classifier
class UnifiedModel(nn.Module):
    def __init__(self, num_classes=4):
        super(UnifiedModel, self).__init__()
        self.segmentation_model = nn.Sequential(ViTEncoder(), CNNDecoder())
        self.classification_model = VisionTransformer(
            img_size=256, patch_size=16, in_chans=3 + num_classes,
            embed_dim=768, depth=6, num_heads=8, num_classes=num_classes
        )

    def forward(self, x):
        segmentation_map, _ = self.segmentation_model(x)
        segmentation_map = F.interpolate(segmentation_map, size=(256, 256), mode="bilinear", align_corners=False)
        combined_input = torch.cat((x, segmentation_map), dim=1)
        classification_output = self.classification_model(combined_input)
        return classification_output

# Initialize Model
unified_model = UnifiedModel().to(device)

# Optimizer and Loss
optimizer = torch.optim.Adam(unified_model.parameters(), lr=0.0001)
criterion = nn.CrossEntropyLoss()

# Mixed Precision Training
scaler = torch.amp.GradScaler()

# Training Function
def train_model(model, dataloader, criterion, optimizer, num_epochs=10, checkpoint_path="unified_checkpoint2.pth"):
    start_epoch = 0
    if os.path.exists(checkpoint_path):
        checkpoint = torch.load(checkpoint_path)
        model.load_state_dict(checkpoint['model_state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        start_epoch = checkpoint['epoch'] + 1
        print(f"Resuming training from epoch {start_epoch}")

    model.train()
    for epoch in range(start_epoch, num_epochs):
        running_loss, correct, total = 0.0, 0, 0
        for images, labels in dataloader:
            images, labels = images.to(device), labels.to(device).long()
            optimizer.zero_grad()

            with torch.amp.autocast("cuda"):  # Enables mixed precision
                outputs = model(images)
                loss = criterion(outputs, labels)

            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()

            running_loss += loss.item()
            _, preds = torch.max(outputs, 1)
            correct += (preds == labels).sum().item()
            total += labels.size(0)

        accuracy = correct / total
        print(f"Epoch {epoch+1}, Loss: {running_loss/len(dataloader):.4f}, Accuracy: {accuracy:.4f}")
        torch.save({'epoch': epoch, 'model_state_dict': model.state_dict(), 'optimizer_state_dict': optimizer.state_dict()}, checkpoint_path)

# Evaluation Function
def evaluate_model(model, dataloader):
    model.eval()
    all_preds, all_labels = [], []
    with torch.no_grad():
        for images, labels in dataloader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, preds = torch.max(outputs, 1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    print("Final Classification Report:")
    print(classification_report(all_labels, all_preds))

# Train and Evaluate the Model
train_model(unified_model, train_loader, criterion, optimizer, num_epochs=10)
evaluate_model(unified_model, test_loader)
# Out:
# Epoch 1, Loss: 1.1007, Accuracy: 0.5200
# Epoch 2, Loss: 0.8587, Accuracy: 0.6595
# Epoch 3, Loss: 0.8101, Accuracy: 0.6797
# Epoch 4, Loss: 0.7861, Accuracy: 0.6912
# Epoch 5, Loss: 0.7612, Accuracy: 0.6989
# Epoch 6, Loss: 0.7447, Accuracy: 0.7081
# Epoch 7, Loss: 0.7287, Accuracy: 0.7140
# Epoch 8, Loss: 0.7149, Accuracy: 0.7206
# Epoch 9, Loss: 0.7119, Accuracy: 0.7217
# Epoch 10, Loss: 0.6963, Accuracy: 0.7301
# Final Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.83      0.84       565
#            1       0.69      0.65      0.67       570
#            2       0.61      0.88      0.72       565
#            3       0.83      0.28      0.42       300
#
#     accuracy                           0.71      2000
#    macro avg       0.75      0.66      0.66      2000
# weighted avg       0.74      0.71      0.69      2000

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import os
import numpy as np
from torch.utils.data import DataLoader
from torchvision import transforms, datasets
from torchvision.datasets import ImageFolder
from sklearn.metrics import classification_report
from timm.models.vision_transformer import VisionTransformer
import matplotlib.pyplot as plt

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Data transformations with standard normalization
transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Load dataset
data_dir = "/content/drive/MyDrive/DeepCMorph-main/data/biomedical/biomedical"
train_dataset = ImageFolder(root=os.path.join(data_dir, "train"), transform=transform)
test_dataset = ImageFolder(root=os.path.join(data_dir, "test"), transform=transform)

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False, num_workers=2)

torch.cuda.empty_cache()

# Vision Transformer Encoder with pretrained weights
class ViTEncoder(nn.Module):
    def __init__(self, img_size=256, patch_size=8, embed_dim=768, depth=6, num_heads=8):
        super(ViTEncoder, self).__init__()
        self.vit = VisionTransformer(
            img_size=img_size, patch_size=patch_size, in_chans=3,
            embed_dim=embed_dim, depth=depth, num_heads=num_heads, num_classes=0
        )

    def forward(self, x):
        x = self.vit.patch_embed(x)
        x = self.vit.pos_drop(x)
        for blk in self.vit.blocks:
            x = blk(x)
        batch_size, num_patches, embed_dim = x.shape  # Debug shape
        side_length = int(num_patches ** 0.5)  # Ensure correct reshaping
        return x.transpose(1, 2).view(batch_size, embed_dim, side_length, side_length)

# CNN-based Decoder with improved architecture
class CNNDecoder(nn.Module):
    def __init__(self, embed_dim=768, num_classes=4):
        super(CNNDecoder, self).__init__()
        self.conv1 = nn.Conv2d(embed_dim, 256, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(256, 128, kernel_size=3, padding=1)
        self.conv3 = nn.Conv2d(128, num_classes, kernel_size=3, padding=1)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        segmentation_map = self.conv3(x)
        classification_map = torch.argmax(segmentation_map, dim=1, keepdim=True)
        return segmentation_map, classification_map

# Unified Model with ViT Classifier
class UnifiedModel(nn.Module):
    def __init__(self, num_classes=4):
        super(UnifiedModel, self).__init__()
        self.segmentation_model = nn.Sequential(ViTEncoder(), CNNDecoder())
        self.classification_model = VisionTransformer(
            img_size=256, patch_size=8, in_chans=3 + num_classes,
            embed_dim=768, depth=6, num_heads=8, num_classes=num_classes
        )

    def forward(self, x):
        segmentation_map, _ = self.segmentation_model(x)
        segmentation_map = F.interpolate(segmentation_map, size=(256, 256), mode="bilinear", align_corners=False)
        combined_input = torch.cat((x, segmentation_map), dim=1)
        classification_output = self.classification_model(combined_input)
        return classification_output

# Initialize Model
unified_model = UnifiedModel().to(device)

# Optimizer and Loss
optimizer = torch.optim.Adam(unified_model.parameters(), lr=0.0001)
criterion = nn.CrossEntropyLoss()

# Mixed Precision Training
scaler = torch.cuda.amp.GradScaler()

# Training Function
def train_model(model, dataloader, criterion, optimizer, num_epochs=10, checkpoint_path="unified_checkpoint.pth"):
    start_epoch = 0
    if os.path.exists(checkpoint_path):
        checkpoint = torch.load(checkpoint_path)
        model.load_state_dict(checkpoint['model_state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        start_epoch = checkpoint['epoch'] + 1
        print(f"Resuming training from epoch {start_epoch}")

    model.train()
    for epoch in range(start_epoch, num_epochs):
        running_loss, correct, total = 0.0, 0, 0
        for images, labels in dataloader:
            images, labels = images.to(device), labels.to(device).long()
            optimizer.zero_grad()

            with torch.cuda.amp.autocast():  # Enables mixed precision
                outputs = model(images)
                loss = criterion(outputs, labels)

            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()

            running_loss += loss.item()
            _, preds = torch.max(outputs, 1)
            correct += (preds == labels).sum().item()
            total += labels.size(0)

        accuracy = correct / total
        print(f"Epoch {epoch+1}, Loss: {running_loss/len(dataloader):.4f}, Accuracy: {accuracy:.4f}")
        torch.save({'epoch': epoch, 'model_state_dict': model.state_dict(), 'optimizer_state_dict': optimizer.state_dict()}, checkpoint_path)

# Evaluation Function
def evaluate_model(model, dataloader):
    model.eval()
    all_preds, all_labels = [], []
    with torch.no_grad():
        for images, labels in dataloader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, preds = torch.max(outputs, 1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    print("Final Classification Report:")
    print(classification_report(all_labels, all_preds))

# Train and Evaluate the Model
train_model(unified_model, train_loader, criterion, optimizer, num_epochs=10)
evaluate_model(unified_model, test_loader)
# Out:
# <ipython-input-3-f01c20cca20b>:90: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
# Resuming training from epoch 6
# <ipython-input-3-f01c20cca20b>:109: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():  # Enables mixed precision
# Epoch 7, Loss: 0.7100, Accuracy: 0.7223
# Epoch 8, Loss: 0.7002, Accuracy: 0.7279
# Epoch 9, Loss: 0.6879, Accuracy: 0.7343
# Epoch 10, Loss: 0.6911, Accuracy: 0.7323
# Final Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.85      0.81       565
#            1       0.71      0.56      0.62       570
#            2       0.68      0.74      0.71       565
#            3       0.60      0.63      0.61       300
#
#     accuracy                           0.70      2000
#    macro avg       0.69      0.69      0.69      2000
# weighted avg       0.70      0.70      0.70      2000

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import os
import numpy as np
from torch.utils.data import DataLoader
from torchvision import transforms, datasets
from torchvision.datasets import ImageFolder
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from timm.models.vision_transformer import VisionTransformer

# Use GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Data transformations
transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

# Load dataset
data_dir = "/content/drive/MyDrive/DeepCMorph-main/data/biomedical/biomedical"
train_dataset = ImageFolder(root=os.path.join(data_dir, "train"), transform=transform)
test_dataset = ImageFolder(root=os.path.join(data_dir, "test"), transform=transform)

# DataLoaders
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False, num_workers=2)

# Vision Transformer Encoder
class ViTEncoder(nn.Module):
    def __init__(self, img_size=256, patch_size=16, in_chans=3, embed_dim=768, depth=6, num_heads=8):
        super(ViTEncoder, self).__init__()
        self.vit = VisionTransformer(img_size=img_size, patch_size=patch_size, in_chans=in_chans,
                                     embed_dim=embed_dim, depth=depth, num_heads=num_heads, num_classes=0)

    def forward(self, x):
        x = self.vit.patch_embed(x)  # Extract patch embeddings
        x = self.vit.pos_drop(x)     # Apply positional embeddings
        for blk in self.vit.blocks:
            x = blk(x)               # Pass through transformer blocks
        return x.transpose(1, 2).view(x.shape[0], 768, 16, 16)  # Reshape for CNN Decoder

# CNN-based Decoder with Attention Layers
class CNNDecoder(nn.Module):
    def __init__(self, embed_dim=768, num_classes=4):
        super(CNNDecoder, self).__init__()
        self.conv1 = nn.ConvTranspose2d(embed_dim, 128, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.ConvTranspose2d(128, num_classes, kernel_size=3, stride=1, padding=1)
        self.attn = nn.MultiheadAttention(embed_dim, num_heads=8)

    def forward(self, x):
        x = x.flatten(2).permute(2, 0, 1)  # Flatten spatial dimensions and permute
        x, _ = self.attn(x, x, x)
        x = x.permute(1, 2, 0).view(x.shape[1], 768, 16, 16)  # Reshape to match image dimensions
        x = F.relu(self.conv1(x))
        x = self.conv2(x)
        return x

# Segmentation Model
class SegmentationModel(nn.Module):
    def __init__(self):
        super(SegmentationModel, self).__init__()
        self.encoder = ViTEncoder()
        self.decoder = CNNDecoder()

    def forward(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x

seg_model = SegmentationModel().to(device)

# Classification Model (Vision Transformer)
class ClassificationModel(nn.Module):
    def __init__(self, num_classes=4):
        super(ClassificationModel, self).__init__()
        self.vit = VisionTransformer(img_size=256, patch_size=16, in_chans=3, embed_dim=768, depth=6, num_heads=8, num_classes=num_classes)

    def forward(self, x):
        return self.vit(x)

clf_model = ClassificationModel(num_classes=4).to(device)

# Training function with checkpoints
def train_model(model, dataloader, criterion, optimizer, num_epochs=10, checkpoint_path="checkpoint.pth"):
    model.train()
    for epoch in range(num_epochs):
        running_loss = 0.0
        correct, total = 0, 0
        for images, labels in dataloader:
            images, labels = images.to(device), labels.to(device).long()
            optimizer.zero_grad()
            outputs = model(images)
            if outputs.dim() == 4:  # If segmentation output
                 labels = labels.view(labels.shape[0], 1, 1).expand(-1, outputs.shape[2], outputs.shape[3])
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
            _, preds = torch.max(outputs, 1)
            correct += (preds == labels).sum().item()
            total += labels.numel()
        accuracy = correct / total
        print(f"Epoch {epoch+1}/{num_epochs}, Loss: {running_loss/len(dataloader):.4f}, Accuracy: {accuracy:.4f}")
        torch.save(model.state_dict(), checkpoint_path)

# Function to calculate evaluation metrics
def evaluate_model(model, dataloader):
    model.eval()
    all_preds = []
    all_labels = []
    with torch.no_grad():
        for images, labels in dataloader:
            images, labels = images.to(device), labels.to(device).long()
            outputs = model(images)
            _, preds = torch.max(outputs, 1)
            all_preds.extend(preds.view(-1).cpu().numpy())
            all_labels.extend(labels.view(-1).cpu().numpy())

    accuracy = accuracy_score(all_labels, all_preds)
    precision = precision_score(all_labels, all_preds, average='macro', zero_division=0)
    recall = recall_score(all_labels, all_preds, average='macro', zero_division=0)
    f1 = f1_score(all_labels, all_preds, average='macro', zero_division=0)
    conf_matrix = confusion_matrix(all_labels, all_preds)

    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1 Score: {f1:.4f}")
    print("Confusion Matrix:")
    print(conf_matrix)

# Train segmentation model
seg_optimizer = torch.optim.Adam(seg_model.parameters(), lr=0.001)
seg_criterion = nn.CrossEntropyLoss()
train_model(seg_model, train_loader, seg_criterion, seg_optimizer, num_epochs=10, checkpoint_path="segmentation_checkpoint.pth")
# Train classification model
clf_optimizer = torch.optim.Adam(clf_model.parameters(), lr=0.001)
clf_criterion = nn.CrossEntropyLoss()
train_model(clf_model, train_loader, clf_criterion, clf_optimizer, num_epochs=10, checkpoint_path="classification_checkpoint.pth")
# Evaluate models
evaluate_model(seg_model, test_loader)
evaluate_model(clf_model, test_loader)
print("Pipeline complete!")
# Out:
# Epoch 1/10, Loss: 2.1798, Accuracy: 0.3322
# Epoch 2/10, Loss: 1.2906, Accuracy: 0.3501
# Epoch 3/10, Loss: 1.2881, Accuracy: 0.3501
# Epoch 4/10, Loss: 1.2879, Accuracy: 0.3501
# Epoch 5/10, Loss: 1.2881, Accuracy: 0.3501
# Epoch 6/10, Loss: 1.2880, Accuracy: 0.3501
# Epoch 7/10, Loss: 1.2880, Accuracy: 0.3501
# Epoch 8/10, Loss: 1.2880, Accuracy: 0.3501
# Epoch 9/10, Loss: 1.2879, Accuracy: 0.3501
# Epoch 10/10, Loss: 1.2880, Accuracy: 0.3501
# Epoch 1/10, Loss: 1.2278, Accuracy: 0.4609
# Epoch 2/10, Loss: 1.1994, Accuracy: 0.4526
# Epoch 3/10, Loss: 1.1918, Accuracy: 0.4621
# Epoch 4/10, Loss: 1.1651, Accuracy: 0.4801

# %%
import torch
import torch.nn as nn
from torchvision.models import swin_t, Swin_T_Weights
from torchvision.models.feature_extraction import create_feature_extractor

class UpsampleConvLayer(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, stride=2):
        super(UpsampleConvLayer, self).__init__()
        self.upconv = nn.ConvTranspose2d(in_channels, out_channels, kernel_size=kernel_size, stride=stride)
        self.relu = nn.LeakyReLU(0.2)

    def forward(self, x):
        out = self.upconv(x)
        out = self.relu(out)
        return out

class DoubleConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(DoubleConv, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, 3, 1, 1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.LeakyReLU(0.2),
            nn.Conv2d(out_channels, out_channels, 3, 1, 1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.LeakyReLU(0.2)
        )

    def forward(self, x):
        return self.conv(x)

class DeepCMorphSegmentationModule(nn.Module):
    def __init__(self, use_skips=False, num_classes=7):
        super(DeepCMorphSegmentationModule, self).__init__()
        net = swin_t(weights=Swin_T_Weights.DEFAULT)

        self.return_nodes = {
            "features.2": "f1",
            "features.3": "f2",
            "features.4": "f3",
            "features.5": "f4"
        }
        self.encoder = create_feature_extractor(net, return_nodes=self.return_nodes)
        for p in self.encoder.parameters():
            p.requires_grad = True

        self.upsample_1 = UpsampleConvLayer(768, 512, 2)
        self.upsample_2 = UpsampleConvLayer(512, 256, 2)
        self.upsample_3 = UpsampleConvLayer(256, 128, 2)
        self.upsample_4 = UpsampleConvLayer(128, 64, 2)

        self.conv_1 = DoubleConv(1280, 512)
        self.conv_2 = DoubleConv(768, 256)
        self.conv_3 = DoubleConv(384, 128)
        self.conv_4 = DoubleConv(64, 64)

        self.conv_segmentation = nn.Conv2d(64, 1, 3, 1, padding="same")
        self.conv_classification = nn.Conv2d(64, num_classes, 3, 1, padding="same")
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        features = self.encoder(x)
        net = self.conv_1(torch.cat((self.upsample_1(features["f4"]), features["f3"]), dim=1))
        net = self.conv_2(torch.cat((self.upsample_2(net), features["f2"]), dim=1))
        net = self.conv_3(torch.cat((self.upsample_3(net), features["f1"]), dim=1))
        net = self.conv_4(self.upsample_4(net))

        predictions_segmentation = self.sigmoid(self.conv_segmentation(net))
        predictions_classification = self.sigmoid(self.conv_classification(net))

        return predictions_segmentation, predictions_classification

class DeepCMorph(nn.Module):
    def __init__(self, num_classes=41, dropout_rate=0.0, freeze_classification_module=False, freeze_segmentation_module=True):
        super(DeepCMorph, self).__init__()
        self.num_classes = num_classes
        self.use_dropout = dropout_rate > 0
        self.dropout = nn.Dropout(dropout_rate)

        self.model_preprocessing = DeepCMorphSegmentationModule()
        for p in self.model_preprocessing.parameters():
            p.requires_grad = not freeze_segmentation_module

        swin_backbone = swin_t(weights=Swin_T_Weights.DEFAULT)
        self.return_nodes = {"flatten": "features"}
        self.encoder = create_feature_extractor(swin_backbone, return_nodes=self.return_nodes)
        # self.encoder.features[0] = nn.Conv2d(11, 96, 4, stride=4, padding=0, bias=False)
        # Assuming the first layer is a Conv2d, reassign it dynamically
        first_layer = list(self.encoder.features.children())[0]
        if isinstance(first_layer, nn.Conv2d):
            new_conv = nn.Conv2d(11, first_layer.out_channels, kernel_size=first_layer.kernel_size,
                                stride=first_layer.stride, padding=first_layer.padding, bias=first_layer.bias)
            self.encoder.features._modules[list(self.encoder.features._modules.keys())[0]] = new_conv

        for p in self.encoder.parameters():
            p.requires_grad = not freeze_classification_module

        self.output = nn.Linear(768, num_classes)
        self.output_41 = nn.Linear(768, 41)
        self.output_32 = nn.Linear(768, 32)
        self.output_9 = nn.Linear(768, 9)

    def forward(self, x, return_features=False, return_segmentation_maps=False):
        nuclei_segmentation_map, nuclei_classification_maps = self.model_preprocessing(x)
        if return_segmentation_maps:
            return nuclei_segmentation_map, nuclei_classification_maps

        x = torch.cat((nuclei_segmentation_map, nuclei_classification_maps, x), dim=1)
        x = self.encoder(x)
        # Ensure feature maps have the correct dimensions

        if x.ndim == 3:  # If the output lacks spatial dimensions
            batch_size, seq_len, channels = x.shape
            height = width = int(seq_len ** 0.5)
            x = x.view(batch_size, channels, height, width)
        extracted_features = x["features"]

        if return_features:
            return extracted_features
        if self.use_dropout:
            extracted_features = self.dropout(extracted_features)

        if self.num_classes == 41:
            return self.output_41(extracted_features)
        if self.num_classes == 32:
            return self.output_32(extracted_features)
        if self.num_classes == 9:
            return self.output_9(extracted_features)
        return self.output(extracted_features)

# %%
# Replace the URL with your file's download link
# !wget https://zenodo.org/records/1214456/files/NCT-CRC-HE-100K-NONORM.zip?download=1.zip -O downloaded_file.zip
# Out:
# --2025-02-26 11:21:16--  https://zenodo.org/records/1214456/files/NCT-CRC-HE-100K-NONORM.zip?download=1.zip
# Resolving zenodo.org (zenodo.org)... 188.185.45.92, 188.185.43.25, 188.185.48.194, ...
# Connecting to zenodo.org (zenodo.org)|188.185.45.92|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11726652899 (11G) [application/octet-stream]
# Saving to: ‘downloaded_file.zip’
#
# downloaded_file.zip 100%[===================>]  10.92G  14.8MB/s    in 45m 39s
#
# 2025-02-26 12:06:56 (4.08 MB/s) - ‘downloaded_file.zip’ saved [11726652899/11726652899]

# %%
                                                                                  # Unzipping the downloaded file
# !unzip /content/biomedical.zip -d /content/destination_folder/

# %%
test_data_dir = "/content/destination_folder/biomedical/train"

# Load test dataset
test_transforms = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

test_dataset = ImageFolder(root=test_data_dir, transform=test_transforms)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=4)

# Load trained model
model.load_state_dict(torch.load("swin_crc_model.pth"))
model.eval()

# Test the model
correct = 0
total = 0
with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.cuda(), labels.cuda()
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

accuracy = 100 * correct / total
print(f"Test Accuracy: {accuracy:.2f}%")

# %%
# Copyright 2024 by Andrey Ignatov. All Rights Reserved.

import torch
from torchvision import datasets, transforms
from torch.utils import data
import imageio
import numpy as np

from model import DeepCMorph

np.random.seed(42)

# Modify the target number of classes and the path to the dataset
NUM_CLASSES = 32
PATH_TO_SAMPLE_FOLDER = "//content/drive/MyDrive/DeepCMorph-main/data/sample_TCGA_images"


if __name__ == '__main__':

    torch.backends.cudnn.deterministic = True
    device = torch.device("cuda")

    # Defining the model
    model = DeepCMorph(num_classes=NUM_CLASSES)
    # Loading model weights corresponding to the TCGA Pan Cancer dataset
    # Possible dataset values:  TCGA, TCGA_REGULARIZED, CRC, COMBINED
    model.load_weights(dataset="TCGA")

    model.to(device)
    model.eval()

    # Loading test images
    test_transforms = transforms.Compose([transforms.ToTensor()])
    test_dataset = datasets.ImageFolder(PATH_TO_SAMPLE_FOLDER, transform=test_transforms)
    test_dataloader = data.DataLoader(test_dataset, batch_size=1, shuffle=False, num_workers=4, pin_memory=False, drop_last=False)
    TEST_SIZE = len(test_dataloader.dataset)

    print("1. Running sample inference")

    with torch.no_grad():

        image_id = 0

        test_iter = iter(test_dataloader)
        for j in range(len(test_dataloader)):

            image, labels = next(test_iter)
            image = image.to(device, non_blocking=True)
            labels = labels.to(device, non_blocking=True)

            # Get the predicted class for each input images
            predictions = model(image)
            _, predictions = torch.max(predictions.data, 1)

            predictions = predictions.detach().cpu().numpy()[0]
            targets = labels.detach().cpu().numpy()[0]

            print("Image %d: predicted class: %d, target class: %d" % (image_id, predictions, targets))
            image_id += 1

    print("2. Generating feature maps for sample input images")

    with torch.no_grad():

        feature_maps = np.zeros((TEST_SIZE, 2560))

        image_id = 0

        test_iter = iter(test_dataloader)
        for j in range(len(test_dataloader)):

            image, labels = next(test_iter)
            image = image.to(device, non_blocking=True)
            labels = labels.to(device, non_blocking=True)

            # Get feature vector of size 2560 for each input images
            image_features = model(image, return_features=True)

            image_features = image_features.detach().cpu().numpy()[0]
            feature_maps[image_id] = image_features

            print("Image " + str(image_id) + ", generated features:", image_features)
            image_id += 1

        print("Features generated, feature array shape:", feature_maps.shape)

    print("3. Generating segmentation and classification maps for sample images")

    with torch.no_grad():

        feature_maps = np.zeros((TEST_SIZE, 2560))

        image_id = 0

        test_iter = iter(test_dataloader)
        for j in range(len(test_dataloader)):

            image, labels = next(test_iter)
            image = image.to(device, non_blocking=True)
            labels = labels.to(device, non_blocking=True)

            # Get predicted segmentation and classification maps for each input images
            nuclei_segmentation_map, nuclei_classification_maps = model(image, return_segmentation_maps=True)

            # Visualizing the predicted segmentation map
            nuclei_segmentation_map = nuclei_segmentation_map.detach().cpu().numpy()[0].transpose(1,2,0) * 255
            nuclei_segmentation_map = np.dstack((nuclei_segmentation_map, nuclei_segmentation_map, nuclei_segmentation_map))

            # Visualizing the predicted nuclei classification map
            nuclei_classification_maps = nuclei_classification_maps.detach().cpu().numpy()[0].transpose(1, 2, 0)
            nuclei_classification_maps = np.argmax(nuclei_classification_maps, axis=2)

            nuclei_classification_maps_visualized = np.zeros((nuclei_classification_maps.shape[0], nuclei_classification_maps.shape[1], 3))
            nuclei_classification_maps_visualized[nuclei_classification_maps == 1] = [255, 0, 0]
            nuclei_classification_maps_visualized[nuclei_classification_maps == 2] = [0, 255, 0]
            nuclei_classification_maps_visualized[nuclei_classification_maps == 3] = [0, 0, 255]
            nuclei_classification_maps_visualized[nuclei_classification_maps == 4] = [255, 255, 0]
            nuclei_classification_maps_visualized[nuclei_classification_maps == 5] = [255, 0, 255]
            nuclei_classification_maps_visualized[nuclei_classification_maps == 6] = [0, 255, 255]

            image = image.detach().cpu().numpy()[0].transpose(1,2,0) * 255

            # Saving visual results
            combined_image = np.hstack((image, nuclei_segmentation_map, nuclei_classification_maps_visualized))
            imageio.imsave("sample_visual_results/" + str(image_id) + ".jpg", combined_image.astype(np.uint8))
            image_id += 1

        print("All visual results saved")
# Out:
# /content/drive/.shortcut-targets-by-id/1MazSsHw39PjoV3bDe39rsZcCpvEVrvQN/DeepCMorph-main/model.py:185: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   missing_keys, unexpected_keys = self.load_state_dict(torch.load(path_to_checkpoints), strict=False)
# Model loaded, unexpected keys: []
# 1. Running sample inference
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Image 0: predicted class: 0, target class: 0
# Image 1: predicted class: 15, target class: 1
# Image 2: predicted class: 2, target class: 2
# Image 3: predicted class: 30, target class: 3
# Image 4: predicted class: 30, target class: 4
# Image 5: predicted class: 5, target class: 5
# Image 6: predicted class: 6, target class: 6
# Image 7: predicted class: 30, target class: 7
# Image 8: predicted class: 8, target class: 8
# Image 9: predicted class: 9, target class: 9
# Image 10: predicted class: 10, target class: 10
# Image 11: predicted class: 11, target class: 11
# Image 12: predicted class: 12, target class: 12
# Image 13: predicted class: 13, target class: 13
# Image 14: predicted class: 14, target class: 14
# Image 15: predicted class: 15, target class: 15
# Image 16: predicted class: 16, target class: 16
# Image 17: predicted class: 23, target class: 17
# Image 18: predicted class: 6, target class: 18
# Image 19: predicted class: 19, target class: 19
# Image 20: predicted class: 20, target class: 20
# Image 21: predicted class: 21, target class: 21
# Image 22: predicted class: 6, target class: 22
# Image 23: predicted class: 23, target class: 23
# Image 24: predicted class: 24, target class: 24
# Image 25: predicted class: 1, target class: 25
# Image 26: predicted class: 26, target class: 26
# Image 27: predicted class: 27, target class: 27
# Image 28: predicted class: 28, target class: 28
# Image 29: predicted class: 15, target class: 29
# Image 30: predicted class: 1, target class: 30
# Image 31: predicted class: 31, target class: 31
# 2. Generating feature maps for sample input images
# Image 0, generated features: [ 0.09661436  0.7565933   0.85258496 ...  0.50930077  1.3802593
#  -0.22617278]
# Image 1, generated features: [-0.0480627  -0.06547289  0.11773393 ... -0.09873092 -0.1402942
#   0.19650188]
# Image 2, generated features: [-0.22951236  0.574791   -0.16981974 ... -0.21142265  0.99730676
#   0.05902923]
# Image 3, generated features: [ 5.1775736e-01 -5.6972727e-05 -5.5699971e-02 ... -1.8300757e-01
#  -2.5306079e-01  1.0250653e-01]
# Image 4, generated features: [-0.03492402  0.5695753   0.61995834 ...  0.04809394 -0.17951846
#   0.03401514]
# Image 5, generated features: [ 0.61910236  0.8715013   1.7805638  ...  0.4636402   0.16354834
#  -0.1089848 ]
# Image 6, generated features: [ 0.6694299   0.26798564 -0.19181338 ...  0.01232092 -0.060251
#  -0.14311977]
# Image 7, generated features: [ 0.64699686 -0.23490113  0.34612828 ... -0.09328896 -0.15621215
#   0.1942631 ]
# Image 8, generated features: [ 0.00207397  0.9181963   0.06131602 ...  0.05478167  0.12346299
#  -0.0119744 ]
# Image 9, generated features: [0.00154245 0.58952117 0.25464535 ... 0.12481635 0.47070736 0.13240881]
# Image 10, generated features: [-0.02599238 -0.0898956  -0.13576819 ...  0.6021186  -0.20275548
#   0.06461591]
# Image 11, generated features: [-0.09333581 -0.16166261  0.02407818 ...  0.2201795   0.44118774
#   0.12881984]
# Image 12, generated features: [ 0.18929294 -0.03742407 -0.07624774 ... -0.23565307  0.05944012
#   0.05883946]
# Image 13, generated features: [ 0.01307355 -0.10251123 -0.13531601 ...  0.14998336  1.2421861
#  -0.19271109]
# Image 14, generated features: [ 0.1521447  -0.09344079  0.1604638  ... -0.14822748 -0.13464895
#   0.1650183 ]
# Image 15, generated features: [ 0.1511134   0.38566667 -0.1683166  ...  0.11271569 -0.20474315
#   0.57377356]
# Image 16, generated features: [-0.20697436  0.00465191  0.17102957 ...  0.4513709   0.19922897
#   0.01433565]
# Image 17, generated features: [-0.21602957  0.46168515  0.17495146 ...  0.06275317  0.43149695
#   0.23924541]
# Image 18, generated features: [-0.0994897   0.12657574 -0.22810754 ...  0.10044915  0.30168015
#   0.03277458]
# Image 19, generated features: [ 0.24388267  0.37690163  0.26728743 ... -0.11561422  0.08213406
#  -0.00255499]
# Image 20, generated features: [0.06711967 0.32696602 1.3206102  ... 1.7895782  1.3482221  0.5260379 ]
# Image 21, generated features: [ 0.48091456  1.0706112   0.28183836 ... -0.05370763  0.50226337
#  -0.20213804]
# Image 22, generated features: [ 0.36957157  0.05906503 -0.09388478 ... -0.09780861 -0.01166284
#  -0.10864547]
# Image 23, generated features: [0.50774366 2.068979   0.50715214 ... 0.076455   1.225367   1.1378074 ]
# Image 24, generated features: [-0.03373845  0.01895209 -0.00366076 ...  0.56037676  0.01999889
#   0.6003845 ]
# Image 25, generated features: [-0.18216905  0.0478164  -0.11336033 ...  0.00363292  0.2555285
#   0.27972615]
# Image 26, generated features: [0.16302085 0.95470154 0.6044983  ... 0.2289992  1.0223392  0.09438827]
# Image 27, generated features: [ 0.68545246  0.9772878   0.28411517 ... -0.0877824   2.123159
#  -0.23276934]
# Image 28, generated features: [ 0.5845068   0.14615747  0.4408481  ... -0.25785455  0.08972134
#   0.03178212]
# Image 29, generated features: [0.03527794 0.7886593  0.6520028  ... 0.44703743 0.69797975 1.310019  ]
# Image 30, generated features: [ 0.6166405  -0.22686878 -0.1426699  ...  0.22634219  0.4201344
#  -0.02197354]
# Image 31, generated features: [ 1.6179706   0.8521726   1.3556764  ...  0.14303233 -0.13668695
#   0.731597  ]
# Features generated, feature array shape: (32, 2560)
# 3. Generating segmentation and classification maps for sample images
# All visual results saved

# %%
# Copyright 2024 by Andrey Ignatov. All Rights Reserved.

import torch
from torchvision import datasets, transforms
from torch.utils import data
import numpy as np

np.random.seed(42)

NUM_CLASSES = 4
BATCH_SIZE = 64

PATH_TO_TEST_DATASET = "/content/drive/MyDrive/DeepCMorph-main/data/biomedical/biomedical/train"

from model import DeepCMorph

# Modify the model training parameters below:

from sklearn.metrics import accuracy_score, balanced_accuracy_score


if __name__ == '__main__':

    torch.backends.cudnn.deterministic = True
    device = torch.device("cuda")

    model = DeepCMorph(num_classes=NUM_CLASSES)
    model.load_weights(dataset="TCGA")

    model.to(device)
    model.eval()

    test_transforms = transforms.Compose([transforms.ToTensor()])
    test_dataset = datasets.ImageFolder(PATH_TO_TEST_DATASET, transform=test_transforms)
    test_dataloader = data.DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=4, pin_memory=False, drop_last=False)

    TEST_SIZE = len(test_dataloader.dataset)
    print("Test size:", TEST_SIZE)

    print("Running Evaluation...")

    accuracy_total = 0.0

    targets_array = []
    predictions_array = []

    with torch.no_grad():

        test_iter = iter(test_dataloader)
        for j in range(len(test_dataloader)):

            image, labels = next(test_iter)
            image = image.to(device, non_blocking=True)
            labels = labels.to(device, non_blocking=True)

            predictions = model(image)
            _, predictions = torch.max(predictions.data, 1)

            predictions = predictions.detach().cpu().numpy()
            targets = labels.detach().cpu().numpy()

            for k in range(targets.shape[0]):

                target = targets[k]
                predicted = predictions[k]

                targets_array.append(target)
                predictions_array.append(predicted)

        print("Accuracy: " + str(accuracy_score(targets_array, predictions_array)))
        print("Balanced Accuracy: " + str(balanced_accuracy_score(targets_array, predictions_array)))
# Out:
# /content/drive/.shortcut-targets-by-id/1MazSsHw39PjoV3bDe39rsZcCpvEVrvQN/DeepCMorph-main/model.py:185: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   missing_keys, unexpected_keys = self.load_state_dict(torch.load(path_to_checkpoints), strict=False)
# Model loaded, unexpected keys: []
# Test size: 20444
# Running Evaluation...
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Accuracy: 0.2688319311289376
# Balanced Accuracy: 0.24926843052580405

# %%
# !rm /content/drive/.shortcut-targets-by-id/1MazSsHw39PjoV3bDe39rsZcCpvEVrvQN/DeepCMorph-main/.git/index.lock

# %%
# !git config --global user.email "sreeramangina@gmail.com"
# !git config --global user.name "Sreeram1004"

# %%
# Navigate to your Git director
# Add all changes
# !git add .
# Commit changes
# !git commit -m "Initial commit with dataset files"
# Out:
# Streaming output truncated to the last 5000 lines.
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QDTRTSSE.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QDVMHGFI.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QDWFHKKV.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QDYFLQQI.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QDYHKCTN.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QDYPVDQA.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QEAKNGPA.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QEAPWWKP.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QEAWPLKP.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QECVAECT.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QEDCVQEK.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QEEEMTSY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QEEKWGDN.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QEELHESQ.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QEFDFRYF.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QEGTFKAN.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QEHHMAEP.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QEIDLSQG.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QEIHIHLE.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QEINWAAC.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QEKHNRPG.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QEKLQTMY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QEKMDYEQ.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QEKWCIVA.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QELKMPQW.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QEMFQVWL.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QENSQIPP.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QENTMMHF.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QENVRHLM.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QEPNHYTK.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QEPPVNRD.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QEQLHRTW.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QEQPMNTI.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QEQQMYND.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QESITQWS.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QETFTLAN.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QETICAEG.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QETTSLPD.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QEVCDHDG.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QEVLSEWW.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QEWIAHIN.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QEWNNGDM.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QEWRDLPD.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QEWRQHLQ.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QEYRIDRQ.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QFALDWNA.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QFAPNYEM.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QFCWSFWP.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QFCYESPH.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QFDLMGYP.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QFDWYGDT.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QFEECWSR.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QFFLHGIE.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QFFQGEQM.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QFFWCYCP.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QFFYRPFS.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QFGSQHMR.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QFHDAQTI.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QFLKHEDC.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QFLNMFHI.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QFLSELMQ.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QFMRPEVR.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QFPMRNCD.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QFPPAQAQ.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QFPTQLYH.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QFQAGLSY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QFQHYSSN.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QFRMIGMW.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QFTGSRFS.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QFVTANMK.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QFWCMISQ.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QFWFPIHI.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QFWLFTVL.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QGAKWEVN.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QGCFGGHM.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QGCKDEQD.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QGDAFNST.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QGDQEKIL.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QGENPVIQ.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QGESGMVE.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QGFDHKQL.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QGFFGSTY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QGHLYSHA.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QGKPLMQG.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QGLFGIQE.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QGLLANDQ.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QGLMSTHI.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QGLRCAYG.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QGLRDDER.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QGMVPHKW.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QGNNEFIS.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QGNNFKQL.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QGNWPRNF.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QGPDQRRK.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QGPYAFVM.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QGQTDTEQ.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QGQWHALM.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QGRDPQTK.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QGRGIFVT.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QGRLWTNE.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QGSRTDGS.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QGSSIHML.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QGTCCFWM.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QGTEPCNT.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QGTNMDYH.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QGWCYFTF.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QGWGEIYY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QHAYDHDM.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QHDFLWID.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QHDIKQMA.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QHECDCLC.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QHEDKQPH.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QHEPEFYW.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QHFSRYDN.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QHFYPHHS.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QHIMSQLT.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QHKLMDND.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QHLPHNVI.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QHMDHCLV.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QHMMFRGE.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QHNSTTYK.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QHPDCLIC.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QHPSNDKY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QHQHKACY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QHQKPADY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QHQPKDVY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QHRGFEFE.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QHSLPILP.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QHSMSFFL.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QHSVPHPI.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QHTNGRCS.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QHVIPNRS.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QHWGWMCQ.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QHWQWDCV.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QHYGTWLK.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QHYRVSMR.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QIAGAYEA.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QIDALYEV.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QIDTYNPY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QIEWAHRN.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QIFIYTPP.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QIFPWRCW.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QIFRDHQS.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QIHNPYID.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QIHPKQRK.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QIHVEVNS.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QIHWHVGK.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QIICHHGK.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QIKKDFKW.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QIKNKPIQ.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QIKQKKWR.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QILGQCKD.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QILNKDWK.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QILWLYGG.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QILYSVKK.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QIMCETPL.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QIMVQLDN.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QIMWAEQT.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QIPVPTRY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QIQGENPK.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QIRCWNPK.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QIRNDAMM.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QITNGKVF.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QITSLGCH.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QIVEAEDD.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QIWIRIPQ.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QIWIVRAN.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QIYTSNKI.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QKAEHCFS.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QKAKTFCY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QKCNYMMT.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QKCVNPYG.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QKDAKREV.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QKEMSSEM.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QKEPFMVR.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QKFDQTAG.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QKGGFCIK.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QKHEMLSM.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QKHFARSK.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QKHKRRNY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QKHQMADP.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QKKGNGHA.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QKKKGFWI.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QKLGYVAT.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QKLMSQSK.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QKMIIMHG.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QKMYFCFN.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QKNVTHNQ.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QKQAILLR.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QKQITAAC.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QKRDACEN.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QKRHTAHY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QKRTRMLR.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QKSHSMYH.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QKTFIVGG.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QKTMKVSC.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QKTQETNY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QKVCIHQC.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QKVRTLSE.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QKYIRYLD.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QKYPRFEY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QLAFCKLA.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QLAIFCRL.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QLCDAAIS.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QLDNRQLK.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QLDVFSQR.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QLEDALGI.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QLEDMTII.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QLEEATWY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QLEPESVW.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QLFEFGAC.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QLGKMRSK.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QLGNPMQT.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QLGPRIGN.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QLGWSSSC.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QLHFAAML.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QLHQVAHF.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QLHSFGVM.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QLHWRQCW.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QLHWSDVN.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QLICKHLA.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QLKHLRWF.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QLLATSWT.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QLLVHVFH.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QLMGHVIE.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QLMSETNT.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QLMYHSEI.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QLNHQVWY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QLNWYGNK.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QLPNRHLG.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QLQFMCKN.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QLQGFWWK.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QLQKRFQF.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QLQSGNIG.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QLSAGVTT.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QLSPIWNG.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QLSWWGIR.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QLTKGDAY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QLTPFHPD.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QLTWPLWL.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QLVLEWVY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QLVSILWI.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QLWCDLYC.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QLWELLYF.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QLWHDASW.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QLWPMFFV.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QLWTCDTK.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QLYHLQSI.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QLYVNYKL.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QMAMRIGD.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QMAWSGGT.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QMCCMKAQ.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QMCMINMV.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QMCVWTHM.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QMCYPHWN.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QMDKQYEY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QMEEKDHV.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QMEYINTN.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QMFWALPG.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QMGDGTWR.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QMGKVRRL.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QMHFQSWN.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QMHHWQRG.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QMIWTPAD.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QMIYITNM.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QMLIFMTR.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QMLSKTRT.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QMMLHNVG.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QMNDNFTE.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QMPMQDPS.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QMPYYMVY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QMQAQKWR.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QMSALSAF.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QMSCEEDM.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QMSTIMWI.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QMTPSQRL.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QMTYMLTV.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QMVGFGKF.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QMVGWGTL.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QMVPTNWT.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QNASYTPR.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QNCYRSIK.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QNDANDCC.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QNDFWVAA.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QNFTMNVN.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QNHSMFTH.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QNHWREDR.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QNIFFHPA.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QNIQCVYP.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QNIRSSCW.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QNKFQMKG.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QNKPMTCM.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QNNLFVWF.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QNNPLIFN.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QNPEIAGC.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QNPKLVYD.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QNPYNHDA.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QNQALQCY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QNQGFSPG.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QNQRNEMW.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QNTHSTKV.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QNVINHFV.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QNVQASLL.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QNWDKKSV.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QNYRGLFL.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QNYYYKWP.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QPADEIGM.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QPAGQTCV.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QPDTWFWR.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QPECLDLD.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QPEIFDEH.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QPELHILY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QPEMWRCM.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QPEWFYPP.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QPFNCQWC.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QPGGKCDY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QPGWHPES.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QPHDVPDV.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QPHNDAAI.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QPIDLLNE.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QPIMDSFL.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QPLEYDDD.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QPLMINWC.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QPLQDEYC.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QPLSRSLR.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QPNFVTRV.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QPNKSPYW.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QPNNIKGG.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QPPACRDH.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QPPFWIRN.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QPPKCIMP.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QPQWPYTV.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QPRFGNTS.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QPRFVWLH.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QPRIPRGE.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QPVCRYCL.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QPWHHWAH.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QPWKRLYL.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QPWQNGGW.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QPYANLFG.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QPYLMIDF.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QPYNEVCP.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QPYWKNGT.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QQATDQPE.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QQCALNAM.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QQCLWQDA.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QQCQFFNA.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QQDCQVVR.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QQDFRDMV.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QQDPPVCG.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QQEFSSDK.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QQENFWMV.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QQFDWRCW.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QQFGMMGF.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QQFVSFER.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QQGDFPWQ.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QQGEQKAC.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QQGKCKIE.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QQHFQAGR.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QQICMWTN.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QQKDGNVP.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QQKINYFK.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QQKKKKSS.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QQKLVINR.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QQKRETFM.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QQKWQQQC.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QQKYILAR.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QQLCKNEF.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QQLVGAYI.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QQNYKDGP.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QQPQFMRT.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QQPQSTGS.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QQQKQMCS.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QQRDMWAA.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QQRLWHFK.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QQSGRYGA.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QQSQREMI.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QQSSNTQR.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QQTEGAKW.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QQTGMESG.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QQTHVITT.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QQVERTKV.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QQWKETAM.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QQWNEHLY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QQYHWCSP.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QQYWMHQR.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QQYWMTKD.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QRAFYMGE.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QRCKDGHE.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QRDEILVW.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QRDLMGLN.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QRDMFCWD.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QRECKYSC.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QREIFLCR.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QRFRGFWS.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QRFRTQHT.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QRFTIWHK.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QRFWWEPP.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QRGSPWNC.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QRGVHVLF.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QRHIWMLH.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QRHQCLAE.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QRHSIHLL.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QRKIAMGH.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QRKQTNLG.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QRLCLPCW.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QRLDIQVT.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QRMHIMNK.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QRMIIAQA.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QRMVKEWH.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QRNGTVCR.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QRNHHYPF.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QRNTMLAG.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QRNTRYRN.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QRQLTTYS.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QRQMDMWS.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QRQPKCSQ.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QRQYDWWQ.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QRRLFHDN.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QRRYKVRL.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QRSGYDSL.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QRSNVAPL.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QRTFIHYP.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QRVENWIV.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QRWEVTVP.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QRWFNRGP.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QRWRDIFM.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QSASKNYE.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QSAWRITV.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QSDHVFLA.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QSETHACT.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QSFLWVWW.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QSFYGAES.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QSGDARIY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QSGRYGDQ.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QSHHVQSQ.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QSIETRLQ.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QSIFLNWP.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QSKAHPSD.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QSKFQWDT.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QSKLAYSD.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QSLAEQYN.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QSMMKRVK.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QSMWCPWA.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QSNKWMDC.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QSNNRGIY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QSNYYTYW.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QSPANTVK.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QSPIIEKA.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QSQFRIKS.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QSQIEGTM.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QSQRIQGS.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QSTGECCR.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QSTQGTYM.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QSTVMCLV.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QSVEMDLL.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QSVFCFWR.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QSVHYKGC.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QSVLTEHK.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QSVVKAWR.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QSWRAREV.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QSYGMPQS.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QSYSKPRF.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QTAWPGEL.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QTCCEMPC.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QTDKQKLF.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QTEIHPAI.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QTEKCGTW.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QTETKSIC.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QTEYTMYL.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QTFPECHR.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QTGIFPRY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QTHSHHWT.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QTINEDKN.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QTKAYHVT.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QTKDSSCT.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QTKMAGAS.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QTKNNHRV.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QTMHKKVS.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QTMVENGC.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QTNHQGEP.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QTNLSWVN.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QTNNRTAP.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QTPHWDFS.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QTPIMSNV.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QTPIVCYG.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QTQRHCEI.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QTVCRCDA.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QTVGDTKH.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QTVTEQEI.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QTWLDDHV.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QTWSCPDM.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QTYIRRGK.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QTYIWSWF.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QTYKADTF.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QVDGPSTL.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QVFSHHGL.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QVGECWIS.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QVHDSRMA.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QVHDVLHM.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QVHEKAKN.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QVHLPRCK.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QVIISIWA.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QVKIRASQ.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QVKQTLPV.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QVLCDWWH.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QVLFQKHY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QVLIHWTK.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QVLRNLSA.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QVMHAPKF.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QVMNTYTD.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QVNMCFKI.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QVNNQTRH.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QVPNEIWN.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QVQVFENG.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QVRAAQYP.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QVRFGTSH.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QVRRSKYY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QVSCTVCY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QVSYLNNP.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QVTADSAH.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QVTETIWK.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QVVCHSMH.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QVVKEERF.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QVVNRYES.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QVWVNNVY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QVYKCKMK.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QVYYYVGH.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QWAQFENS.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QWASSFDK.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QWCEPKEE.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QWDSEEVQ.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QWDTSIGK.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QWDWYSQS.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QWEAQVTH.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QWEMVGQT.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QWFAMESK.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QWFHYRQY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QWFLNPII.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QWFWQWDQ.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QWGQYQEN.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QWHKACTF.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QWKENNCT.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QWKQHCVC.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QWKSDINC.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QWKSHYDL.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QWLCIFCH.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QWMHVIVK.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QWMQLNRW.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QWMRARFI.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QWNSPEMR.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QWNVKMDT.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QWPHWCHV.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QWPINLVC.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QWQDTWWE.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QWRGKIKY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QWSAILCS.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QWSVKIHF.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QWTSTLMD.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QWVLKIRE.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QWWPCQQM.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QWWVLKGF.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QWYCCDWV.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QWYDEAYL.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QWYKVRKE.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QWYYRLAK.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QYACTNWF.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QYAHTKFN.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QYALFDQV.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QYCKHSKL.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QYCVDWFV.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QYCYQHCY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QYDLFWAY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QYFDVDTH.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QYFESFHL.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QYGGKRMQ.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-QYGQSSWP.tif
# ...
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YRDPYLTC.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YRGLGWAL.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YRHEHATY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YRHGRGNM.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YRKHAVYG.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YRNCKTWC.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YRNFFYNR.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YRNLIGAS.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YRNSRKWY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YRPVIDRY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YRQMQPIC.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YRQWVNKD.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YRTMLNGY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YRTYNMQY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YRVAIVTF.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YRVCTPSE.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YRVGCRAN.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YRVKDPFS.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YRVSPRQI.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YRWTIINL.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YRYFQPFM.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YRYIQNKS.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YSATVSHH.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YSCDFLMN.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YSCPIPMW.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YSCRRTRK.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YSCVMKPC.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YSDGDKHA.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YSDGYTVN.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YSDNLPSS.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YSEAHDLM.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YSEANGHK.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YSECHVNT.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YSFANCQG.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YSFMILYL.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YSGPKAQD.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YSHIFCGY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YSHNGHRE.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YSICDCNA.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YSIKWIMG.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YSKEKRVP.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YSKGEIKA.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YSMVPLWI.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YSMYQTWY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YSNNGMKY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YSNRVVKW.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YSPEVWYP.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YSPLLIHR.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YSPPCNCE.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YSQKIISN.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YSQKTYSR.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YSRCWTYR.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YSRHQYQC.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YSRVRGFF.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YSTGHSEQ.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YSTIHHPA.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YSTIRYDF.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YSWKYNGF.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YSWLFIRL.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YSWWVWKG.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YSYASMAV.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YSYCWPWN.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YSYMDNTH.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YSYNNCNY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YTAMKDGH.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YTCDLYTT.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YTCECTAD.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YTCSKMNF.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YTDQRHSR.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YTDRSARC.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YTDYHYAY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YTERHYGE.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YTFKKAHT.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YTIETIAV.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YTKEAVIR.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YTNDAIAL.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YTNEDATL.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YTRFQNRM.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YTSCNGPP.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YTSINPDK.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YTSWSLRF.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YTSWYSYE.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YTTSMIII.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YTVHFLTK.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YTVWFHTK.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YTWDHGKW.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YTWETGED.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YTWGGKCL.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YTWTEDFE.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YTYDVVVV.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YVCRINES.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YVCSLDVG.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YVCYMRFV.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YVDWGTLM.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YVGRIYQH.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YVHGAMWD.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YVIPKVYN.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YVKRWRLP.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YVLRIRQN.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YVMLPNSF.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YVNLQMQE.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YVNMNMAK.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YVNMWITY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YVPATHPG.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YVPRVPCH.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YVRHHSRA.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YVRWMARG.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YVSDRNRQ.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YVSPGTSF.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YVSQGDRN.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YVSVMSER.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YVTMMKSY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YVTMWQQL.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YVTNTVKI.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YVTTEEFY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YVTTKKKG.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YVVEYMCA.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YVVKSSMW.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YVVNRRGE.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YVVNSMTN.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YVWEHWAM.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YVWFWNWM.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YVYGVAMP.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YWAVVGQT.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YWAYIPLV.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YWCTISGE.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YWERHNNE.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YWESICKW.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YWEYNGPG.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YWFCGVTK.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YWFEEMYQ.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YWFFCITQ.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YWFWPMPY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YWGIIILL.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YWGITTLT.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YWGPFPGG.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YWGPHFMV.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YWHIWKIW.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YWHWHILM.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YWIFEMTI.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YWIKTHLY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YWIQNLEC.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YWIRNMWQ.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YWKQFQCK.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YWLKDFRR.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YWMAMYTI.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YWMKFQVQ.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YWMKMTQN.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YWNHSDQC.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YWPVTFEV.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YWQLTSGE.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YWQYLLDQ.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YWSALHHP.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YWSFLTLC.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YWSMPHKV.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YWSMWPYF.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YWTRNAAI.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YWVICCYY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YWWKLYIY.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YWWQCNFR.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YWYAWNDQ.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YWYSYEIQ.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YYECLWNG.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YYEDEINI.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YYEQEFHC.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YYEYYKQP.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YYFWMMED.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YYHIRIYK.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YYIAATER.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YYICWSKE.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YYIWPMWE.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YYKWATLW.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YYMFQQKR.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YYNPMETC.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YYNRDAQM.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YYPCRDMI.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YYPIVIPM.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YYQSVVCG.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YYSSGWQM.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YYTGSMGA.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YYVDFMRP.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YYVNLWGL.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YYWKMWNE.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YYWMMMNW.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YYWWAQYG.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YYYFKYNH.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YYYSGWYW.tif
#  create mode 100644 destination_folder/NCT-CRC-HE-100K-NONORM/TUM/TUM-YYYYQFVN.tif
#  create mode 100644 downloaded_file.zip
#  create mode 100755 sample_data/README.md
#  create mode 100755 sample_data/anscombe.json
#  create mode 100644 sample_data/california_housing_test.csv
#  create mode 100644 sample_data/california_housing_train.csv
#  create mode 100644 sample_data/mnist_test.csv
#  create mode 100644 sample_data/mnist_train_small.csv

# %%
# !git remote add origin https://Sreeram1004:Ratnarams@1978@github.com/Sreeram1004/datasets.git

# %%
# !git branch -M main
# !git push -u origin main
# Out:
# fatal: unable to access 'https://1978@github.com/Sreeram1004/datasets.git/': URL using bad/illegal format or missing URL

# %%
# !git remote rm origin

# %%
import torch
from torchvision.models import swin_t, Swin_T_Weights
from torchvision import datasets, transforms
from torch.utils import data
import imageio
import numpy as np
import torch.nn.functional as F
from sklearn.metrics import accuracy_score, balanced_accuracy_score

# class DeepCSwin(torch.nn.Module):
#     def __init__(self, num_classes=32):
#         super(DeepCSwin, self).__init__()
#         self.num_classes = num_classes
#         # Load Swin Transformer pre-trained weights
#         self.swin_backbone = swin_t(weights=Swin_T_Weights.DEFAULT)
#         self.swin_backbone.head = torch.nn.Identity()  # Remove the original classification head
#         # New classification head
#         self.fc = torch.nn.Linear(768, num_classes)  # swin_t outputs feature dim 768

#     def forward(self, x, return_features=False):
#         features = self.swin_backbone(x)
#         if return_features:
#             return features
#         output = self.fc(features)
#         return output

if __name__ == '__main__':
    np.random.seed(42)
    torch.backends.cudnn.deterministic = True
    device = torch.device("cuda")

    # Model initialization
    model = DeepCMorph(num_classes=32)
   # model.to(device)
    model.eval()

    # Load test images
    PATH_TO_TEST_DATASET = "/content/drive/MyDrive/DeepCMorph-main/data/CRC-VAL-HE-7K/"
    test_transforms = transforms.Compose([transforms.ToTensor()])
    test_dataset = datasets.ImageFolder(PATH_TO_TEST_DATASET, transform=test_transforms)
    test_dataloader = data.DataLoader(test_dataset, batch_size=64, shuffle=False, num_workers=4, pin_memory=False, drop_last=False)

    TEST_SIZE = len(test_dataloader.dataset)
    print("Test size:", TEST_SIZE)

    print("Running Evaluation...")
    targets_array = []
    predictions_array = []

    with torch.no_grad():
        for image, labels in test_dataloader:
            # image = image.to(device)
            # labels = labels.to(device)
            predictions = model(image)
            _, predictions = torch.max(predictions.data, 1)

            predictions_array.extend(predictions.detach().cpu().numpy())
            targets_array.extend(labels.detach().cpu().numpy())

    print("Accuracy:", accuracy_score(targets_array, predictions_array))
    print("Balanced Accuracy:", balanced_accuracy_score(targets_array, predictions_array))

    print("Generating visualizations for sample images...")
    with torch.no_grad():
        image_id = 0
        for image, labels in test_dataloader:
            # image = image.to(device)
            image_features = model(image, return_features=True)
            feature_map = image_features.detach().cpu().numpy()[0].reshape(24, 32)  # Reshape for visualization
            feature_map_visual = (feature_map - feature_map.min()) / (feature_map.max() - feature_map.min()) * 255
            feature_map_visual = np.stack([feature_map_visual] * 3, axis=-1)  # Convert to RGB format

            # Resize feature map to match the input image size
            feature_map_tensor = torch.tensor(feature_map_visual).permute(2, 0, 1).unsqueeze(0)
            feature_map_resized = F.interpolate(feature_map_tensor, size=(256, 256), mode='bilinear', align_corners=False)
            feature_map_visual_resized = feature_map_resized.squeeze(0).permute(1, 2, 0).numpy()

            image_np = image.detach().cpu().numpy()[0].transpose(1, 2, 0) * 255
            combined_image = np.hstack((image_np, feature_map_visual_resized))
            imageio.imsave(f"sample_visual_results/{image_id}.jpg", combined_image.astype(np.uint8))
            image_id += 1

        print("All visual results saved.")
# Out:
# Downloading: "https://download.pytorch.org/models/swin_t-704ceda3.pth" to /root/.cache/torch/hub/checkpoints/swin_t-704ceda3.pth
# 100%|██████████| 108M/108M [00:00<00:00, 141MB/s]
# Test size: 7180
# Running Evaluation...
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-4-1854724eb665> in <cell line: 0>()
#      52             # image = image.to(device)
#      53             # labels = labels.to(device)
# ---> 54             predictions = model(image)
#      55             _, predictions = torch.max(predictions.data, 1)
#      56
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# <ipython-input-3-dca9f7f1b537> in forward(self, x, return_features, return_segmentation_maps)
#     102
#     103     def forward(self, x, return_features=False, return_segmentation_maps=False):
# --> 104         nuclei_segmentation_map, nuclei_classification_maps = self.model_preprocessing(x)
#     105         if return_segmentation_maps:
#     106             return nuclei_segmentation_map, nuclei_classification_maps
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# <ipython-input-3-dca9f7f1b537> in forward(self, x)
#      61     def forward(self, x):
#      62         features = self.encoder(x)
# ---> 63         net = self.conv_1(torch.cat((self.upsample_1(features["f4"]), features["f3"]), dim=1))
#      64         net = self.conv_2(torch.cat((self.upsample_2(net), features["f2"]), dim=1))
#      65         net = self.conv_3(torch.cat((self.upsample_3(net), features["f1"]), dim=1))
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# <ipython-input-3-dca9f7f1b537> in forward(self, x)
#      11
#      12     def forward(self, x):
# ---> 13         out = self.upconv(x)
#      14         out = self.relu(out)
#      15         return out
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py in forward(self, input, output_size)
#    1160         )
#    1161
# -> 1162         return F.conv_transpose2d(
#    1163             input,
#    1164             self.weight,
#
# RuntimeError: Given transposed=1, weight of size [768, 512, 2, 2], expected input[64, 14, 14, 384] to have 768 channels, but got 14 channels instead

# %%
import torch
import torch.nn as nn
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torch.utils.data import DataLoader
from timm import create_model

# Define dataset path
dataset_path = "/content/destination_folder/NCT-CRC-HE-100K-NONORM"

# Define transformations for data augmentation
transform = transforms.Compose([
    transforms.RandomResizedCrop(224, scale=(0.8, 1.0)),  # Random rescaling (0-20%)
    transforms.RandomRotation(360),  # Random rotation
    transforms.RandomAffine(degrees=0, scale=(0.9, 1.1)),  # Aspect ratio adjustment
    transforms.ColorJitter(brightness=0.5, contrast=0.7, saturation=0.3, hue=0.1),  # Color adjustments
    transforms.RandomAdjustSharpness(2),  # Sharpness adjustment
    transforms.GaussianBlur(3),  # Random Gaussian noise
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Load dataset using ImageFolder
dataset = datasets.ImageFolder(root=dataset_path, transform=transform)

# Split dataset into train and validation sets
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(dataset, [train_size, val_size])

# Define data loaders
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=4)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False, num_workers=4)

# Define Swin Transformer model
num_classes = len(dataset.classes)  # Automatically detect number of classes
model = create_model("swin_tiny_patch4_window7_224", pretrained=True, num_classes=num_classes)
model = model.to(torch.device("cuda" if torch.cuda.is_available() else "cpu"))

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=3e-4, weight_decay=1e-2)

# Training loop
def train_model(model, train_loader, val_loader, criterion, optimizer, epochs=10):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.train()
    for epoch in range(epochs):
        total_loss, correct, total = 0, 0, 0
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
            _, predicted = outputs.max(1)
            correct += predicted.eq(labels).sum().item()
            total += labels.size(0)
        print(f"Epoch {epoch+1}/{epochs} | Loss: {total_loss/len(train_loader):.4f} | Accuracy: {correct/total:.4f}")

# Train the model
train_model(model, train_loader, val_loader, criterion, optimizer, epochs=10)

# Save model
torch.save(model.state_dict(), "swin_crc_model.pth")
print("Model saved successfully!")
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
